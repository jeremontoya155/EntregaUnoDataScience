# %% [markdown]
# <a href="https://colab.research.google.com/github/jeremontoya155/EntregaUnoDataScience/blob/main/FactorialSerieMontoya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
def factorial(numero):
    if numero<2:
        return 1
    else:
        return numero*factorial(numero-1)

# %%
#Usamos un numero aleatorio para las acciones
numero=random.randint(1,10)
print("Usamos el numero:"+str(numero))
salida=factorial(numero)
print("El factorial del numero es:"+str(salida))
# Out:
# Usamos el numero:3
# El factorial del numero es:6

# %%
def serie(cotaInferior,cotaSuperior):
    
    acumulador=0
    if cotaInferior>cotaSuperior:
        print("Se trabajara con las cotas invertidas")
        for i in range(cotaSuperior,cotaInferior):
            acumulador+=i
    elif cotaInferior==cotaSuperior:
        acumulador=cotaInferior+cotaSuperior
    else:
        for i in range(cotaInferior,cotaSuperior):
            acumulador+=i

    return acumulador

# %%
numeroA=random.randint(1,10)
numeroB=random.randint(1,10)
print("Numeros para el ejercicio de suma\nPrimer numero:"+str(numeroA)+" Segundo numero:"+str(numeroB))
ejecucion=serie(numeroA,numeroB)
print("Ejecucion de la suma da:"+str(ejecucion))
# Out:
# Numeros para el ejercicio de suma
# Primer numero:3 Segundo numero:9
# Ejecucion de la suma da:33
